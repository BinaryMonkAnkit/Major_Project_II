# %%
# %pip install "unstructured[all-docs]"

# %%
from transformers import DetrImageProcessor
print("Transformers loaded successfully")
# Out:
# Transformers loaded successfully

# %%
# %pip install huggingface_hub

# %%
# pip install torch

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %%
from IPython.display import JSON

import json

from unstructured.partition.html import partition_html
from unstructured.partition.pdf import partition_pdf
from unstructured.staging.base import dict_to_elements, elements_to_json

# %%
# %pip show unstructured

# %%
import unstructured.partition

help(unstructured.partition)
# Out:
# Help on package unstructured.partition in unstructured:
#
# NAME
#     unstructured.partition
#
# PACKAGE CONTENTS
#     api
#     auto
#     common (package)
#     csv
#     doc
#     docx
#     email
#     epub
#     html (package)
#     image
#     json
#     md
#     model_init
#     msg
#     odt
#     org
#     pdf
#     pdf_image (package)
#     ppt
#     pptx
#     rst
#     rtf
#     strategies
#     text
#     text_type
#     tsv
#     utils (package)
#     xlsx
#     xml
#
# FILE
#     c:\users\ankit kumar singh\appdata\roaming\python\python312\site-packages\unstructured\partition\__init__.py

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Ankit kumar
# [nltk_data]     singh\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# from unstructured.partition.pdf import partition_pdf

# Specify the path to your PDF file
# filename = r"C:\Users\Ankit kumar singh\AIML Academics\SEM VIII\Major project\extract_data\extractor\Data\gpt4all.pdf"

# Call the partition_pdf function
# Returns a List[Element] present in the pages of the parsed pdf document
# elements = partition_pdf(filename)

# Now, elements is a list of all elements present in the pages of the parsed pdf document

# %%
# elements

# %%
len(elements)
# Out:
# 134

# %%
element_dict = [el.to_dict() for el in elements]
output = json.dumps(element_dict, indent=2)
print(output)
# Out:
# [
#   {
#     "type": "UncategorizedText",
#     "element_id": "b0c5cfcf93a217591e27d5c97845f59b",
#     "text": "3 2 0 2",
#     "metadata": {
#       "coordinates": {
#         "points": [
#           [
#             16.34,
#             263.81000000000006
#           ],
#           [
#             16.34,
#             303.81000000000006
#           ],
#           [
#             36.34,
#             303.81000000000006
#           ],
#           [
#             36.34,
#             263.81000000000006
#           ]
#         ],
#         "system": "PixelSpace",
#         "layout_width": 595.276,
#         "layout_height": 841.89
#       },
#       "file_directory": "C:\\Users\\Ankit kumar singh\\AIML Academics\\SEM VIII\\Major project\\extract_data\\extractor\\Data",
#       "filename": "gpt4all.pdf",
#       "languages": [
#         "eng"
#       ],
#       "last_modified": "2025-01-01T11:55:10",
#       "page_number": 1,
#       "filetype": "application/pdf"
#     }
#   },
#   {
# ...

# %%
unique_types = set()

for item in element_dict:
    unique_types.add(item['type'])

print(unique_types)
# Out:
# {'Title', 'NarrativeText', 'UncategorizedText'}

# %%
from unstructured.partition.pdf import partition_pdf

# Specify the path to your PDF file
filename = r"C:\Users\Ankit kumar singh\AIML Academics\SEM VIII\Major project\extract_data\extractor\Data\scanned_gpt4all.pdf"

# Call the partition_pdf function
# Returns a List[Element] present in the pages of the parsed pdf document
elements = partition_pdf(filename)

# Now, elements is a list of all elements present in the pages of the parsed pdf document

# %%
elements

# %%
len(elements)
# Out:
# 91

# %%
element_dict = [el.to_dict() for el in elements]
output = json.dumps(element_dict, indent=2)
print(output)
# Out:
# [
#   {
#     "type": "UncategorizedText",
#     "element_id": "2d36d8b847abbb8c43bb7ccc1ca04abb",
#     "text": "2311.04931v1 [cs.CL] 6 Nov 2023",
#     "metadata": {
#       "coordinates": {
#         "points": [
#           [
#             187.0,
#             718.0
#           ],
#           [
#             187.0,
#             1404.0
#           ],
#           [
#             230.0,
#             1404.0
#           ],
#           [
#             230.0,
#             718.0
#           ]
#         ],
#         "system": "PixelSpace",
#         "layout_width": 1700,
#         "layout_height": 2200
#       },
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "last_modified": "2025-01-02T09:28:58",
#       "page_number": 1,
#       "file_directory": "C:\\Users\\Ankit kumar singh\\AIML Academics\\SEM VIII\\Major project\\extract_data\\extractor\\Data",
#       "filename": "scanned_gpt4all.pdf"
#     }
#   },
#   {
#     "type": "Title",
# ...

# %%
from unstructured.partition.pdf import partition_pdf

elements = partition_pdf(filename=filename,
                         infer_table_structure=True,
                         strategy='hi_res',
           )

# %%
len(elements)
# Out:
# 89

# %%
# pip install unstructured[ocr] transformers torch torchvision

# %%
# pip show transformers torch

# %%
element_dict = [el.to_dict() for el in elements]
output = json.dumps(element_dict, indent=2)
print(output)

unique_types = set()

for item in element_dict:
    unique_types.add(item['type'])

print(unique_types)
# Out:
# [
#   {
#     "type": "Header",
#     "element_id": "2d36d8b847abbb8c43bb7ccc1ca04abb",
#     "text": "2311.04931v1 [cs.CL] 6 Nov 2023",
#     "metadata": {
#       "detection_class_prob": 0.4241480231285095,
#       "coordinates": {
#         "points": [
#           [
#             184.932861328125,
#             741.93505859375
#           ],
#           [
#             184.932861328125,
#             1471.6383056640625
#           ],
#           [
#             232.85536193847656,
#             1471.6383056640625
#           ],
#           [
#             232.85536193847656,
#             741.93505859375
#           ]
#         ],
#         "system": "PixelSpace",
#         "layout_width": 1700,
#         "layout_height": 2200
#       },
#       "last_modified": "2025-01-02T09:28:58",
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
# ...

# %%
tables = [el for el in elements if el.category == "Table"]

tables

# %%
print(tables[0].text)
print(tables[0].metadata.text_as_html)
# Out:
# Model BoolQ PIQA HellaSwag WinoG. ARC-c ARC-c OBQA Avg. GPT4AII-J 6B v1.0* 73.4 74.8 63.4 64.7 54.9 36 40.2 58.2 GPT4AII-J v1.1-breezy* 74 75.1 63.2 63.6 55.4 34.9 38.4 57.8 GPT4AII-J v1.2-jazzy* 74.8 74.9 63.6 638 56.6 35.3 41 58.6 GPT4AIIL-J v1.3-groovy* 73.6 74.3 63.8 63.5 57.7 35 38.8 58.1 GPT4AII-J Lora 6B* 68.6 75.8 66.2 63.5 56.4 35.7 402 58.1 GPT4AIl LLaMa Lora 7B* 73.1 716 721 67.8 SIL 40.4 40.2 60.3 GPT4All 13B snoozy* 83.3 79.2 15 71.3 60.9 442 43.4 65.3 GPT4AIl Falcon 71.6 79.8 749 70.1 67.9 43.4 42.6 65.2 Nous-Hermes (Nous-Research, 2023b) 79.5 78.9 80 ng 74.2 50.9 64 68.38 Nous-Hermes2 (Nous-Research, 2023c) 83.9 80.7 80.1 71.3 75.7 52.1 46.2 70.0 Nous-Puffin (Nous-Research, 2023d) 815 80.7 80.4 72.5 771.6 50.7 45.6 69.9 Dolly 6B* (Conover et al., 2023a) 68.8 77.3 67.6 63.9 62.9 38.7 412 60.1 Dolly 12B* (Conover et al., 2023b) 56.7 75.4 ma 62.2 64.6 38.5 40.4 58.4 Alpaca 7B* (Taori et al, 2023) 739 Tt, 73.9 66.1 59.8 43.3 Ba 62.5 Alpaca Lora 7B* ibibo | 2023) 74.3 79.3 
# ...

# %%
tables

# %%
len(tables)
# Out:
# 1

# %%
tables[0].text
# Out:
# 'Model BoolQ PIQA HellaSwag WinoG. ARC-c ARC-c OBQA Avg. GPT4AII-J 6B v1.0* 73.4 74.8 63.4 64.7 54.9 36 40.2 58.2 GPT4AII-J v1.1-breezy* 74 75.1 63.2 63.6 55.4 34.9 38.4 57.8 GPT4AII-J v1.2-jazzy* 74.8 74.9 63.6 638 56.6 35.3 41 58.6 GPT4AIIL-J v1.3-groovy* 73.6 74.3 63.8 63.5 57.7 35 38.8 58.1 GPT4AII-J Lora 6B* 68.6 75.8 66.2 63.5 56.4 35.7 402 58.1 GPT4AIl LLaMa Lora 7B* 73.1 716 721 67.8 SIL 40.4 40.2 60.3 GPT4All 13B snoozy* 83.3 79.2 15 71.3 60.9 442 43.4 65.3 GPT4AIl Falcon 71.6 79.8 749 70.1 67.9 43.4 42.6 65.2 Nous-Hermes (Nous-Research, 2023b) 79.5 78.9 80 ng 74.2 50.9 64 68.38 Nous-Hermes2 (Nous-Research, 2023c) 83.9 80.7 80.1 71.3 75.7 52.1 46.2 70.0 Nous-Puffin (Nous-Research, 2023d) 815 80.7 80.4 72.5 771.6 50.7 45.6 69.9 Dolly 6B* (Conover et al., 2023a) 68.8 77.3 67.6 63.9 62.9 38.7 412 60.1 Dolly 12B* (Conover et al., 2023b) 56.7 75.4 ma 62.2 64.6 38.5 40.4 58.4 Alpaca 7B* (Taori et al, 2023) 739 Tt, 73.9 66.1 59.8 43.3 Ba 62.5 Alpaca Lora 7B* ibibo | 2023) 74.3 79.3
# ...

# %%
tables[0].metadata

# %%
table_html = tables[0].metadata.text_as_html

# %%
table_html
# Out:
# '<table><thead><tr><th>Model</th><th>BoolQ</th><th>PIQA</th><th>HellaSwag</th><th>WinoG.</th><th>ARC-c</th><th>ARC-c</th><th>OBQA</th><th>Avg</th></tr></thead><tbody><tr><td>GPT4AII-J 6B v1.0*</td><td>73.4</td><td>74.8</td><td>63.4</td><td>64.7</td><td>54.9</td><td>36</td><td>40.2</td><td>58.2</td></tr><tr><td>GPT4AII-J v1.1-breezy*</td><td>74</td><td>75.1</td><td>63.2</td><td>63.6</td><td>55.4</td><td>34.9</td><td>38.4</td><td>SL</td></tr><tr><td>GPT4AII-J v1.2-jazzy*</td><td>74.8</td><td>74.9</td><td>63.6</td><td>638</td><td>56.6</td><td>35.3</td><td>41</td><td>58.6</td></tr><tr><td>GPT4AIIL-J v1.3-groovy*</td><td>73.6</td><td>74.3</td><td>63.8</td><td>63.5</td><td>57.7</td><td>35</td><td>38.8</td><td>58.1</td></tr><tr><td>GPT4AII-J Lora 6B*</td><td>68.6</td><td>75.8</td><td>66.2</td><td>63.5</td><td>56.4</td><td>35.7</td><td>402</td><td>58.1</td></tr><tr><td>GPT4AIl LLaMa Lora 7B*</td><td>73.1</td><td>716</td><td>721</td><td>67.8</td><td>SIL</td><td>40.4</td><td>40.2</td><td>60.3<
# ...

# %%
# view what the HTML in the metadata field looks like

from io import StringIO
from lxml import etree

parser = etree.XMLParser(remove_blank_text=True)
file_obj = StringIO(table_html)
tree = etree.parse(file_obj, parser)
print(etree.tostring(tree, pretty_print=True).decode())
# Out:
# <table>
#   <thead>
#     <tr>
#       <th>Model</th>
#       <th>BoolQ</th>
#       <th>PIQA</th>
#       <th>HellaSwag</th>
#       <th>WinoG.</th>
#       <th>ARC-c</th>
#       <th>ARC-c</th>
#       <th>OBQA</th>
#       <th>Avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>GPT4AII-J 6B v1.0*</td>
#       <td>73.4</td>
#       <td>74.8</td>
#       <td>63.4</td>
#       <td>64.7</td>
#       <td>54.9</td>
#       <td>36</td>
#       <td>40.2</td>
#       <td>58.2</td>
#     </tr>
#     <tr>
#       <td>GPT4AII-J v1.1-breezy*</td>
#       <td>74</td>
#       <td>75.1</td>
#       <td>63.2</td>
#       <td>63.6</td>
#       <td>55.4</td>
#       <td>34.9</td>
#       <td>38.4</td>
#       <td>SL</td>
#     </tr>
#     <tr>
#       <td>GPT4AII-J v1.2-jazzy*</td>
#       <td>74.8</td>
#       <td>74.9</td>
#       <td>63.6</td>
#       <td>638</td>
#       <td>56.6</td>
#       <td>35.3</td>
#       <td>41</td>
#       <td>58.6</td>
#     </tr>
#     <tr>
# ...

# %%
# let's display this table

from IPython.core.display import HTML
HTML(table_html)
# Out:
# <table><thead><tr><th>Model</th><th>BoolQ</th><th>PIQA</th><th>HellaSwag</th><th>WinoG.</th><th>ARC-c</th><th>ARC-c</th><th>OBQA</th><th>Avg</th></tr></thead><tbody><tr><td>GPT4AII-J 6B v1.0*</td><td>73.4</td><td>74.8</td><td>63.4</td><td>64.7</td><td>54.9</td><td>36</td><td>40.2</td><td>58.2</td></tr><tr><td>GPT4AII-J v1.1-breezy*</td><td>74</td><td>75.1</td><td>63.2</td><td>63.6</td><td>55.4</td><td>34.9</td><td>38.4</td><td>SL</td></tr><tr><td>GPT4AII-J v1.2-jazzy*</td><td>74.8</td><td>74.9</td><td>63.6</td><td>638</td><td>56.6</td><td>35.3</td><td>41</td><td>58.6</td></tr><tr><td>GPT4AIIL-J v1.3-groovy*</td><td>73.6</td><td>74.3</td><td>63.8</td><td>63.5</td><td>57.7</td><td>35</td><td>38.8</td><td>58.1</td></tr><tr><td>GPT4AII-J Lora 6B*</td><td>68.6</td><td>75.8</td><td>66.2</td><td>63.5</td><td>56.4</td><td>35.7</td><td>402</td><td>58.1</td></tr><tr><td>GPT4AIl LLaMa Lora 7B*</td><td>73.1</td><td>716</td><td>721</td><td>67.8</td><td>SIL</td><td>40.4</td><td>40.2</td><td>60.3</
# ...

# %%
# %pip install langchain-ollama langchain_core langchain_community

# %%
from langchain_ollama import ChatOllama
from langchain_core.documents import Document
from langchain.chains.summarize import load_summarize_chain

# %%
ChatOllama??
# Out:
# Init signature:
# ChatOllama(
#     *args: Any,
#     name: Optional[str] = None,
#     cache: Union[langchain_core.caches.BaseCache, bool, NoneType] = None,
#     verbose: bool = None,
#     callbacks: Union[list[langchain_core.callbacks.base.BaseCallbackHandler], langchain_core.callbacks.base.BaseCallbackManager, NoneType] = None,
#     tags: Optional[list[str]] = None,
#     metadata: Optional[dict[str, Any]] = None,
#     custom_get_token_ids: Optional[Callable[[str], list[int]]] = None,
#     callback_manager: Optional[langchain_core.callbacks.base.BaseCallbackManager] = None,
#     rate_limiter: Optional[langchain_core.rate_limiters.BaseRateLimiter] = None,
#     disable_streaming: Union[bool, Literal['tool_calling']] = False,
#     model: str,
#     mirostat: Optional[int] = None,
#     mirostat_eta: Optional[float] = None,
#     mirostat_tau: Optional[float] = None,
#     num_ctx: Optional[int] = None,
#     num_gpu: Optional[int] = None,
# ...

# %%
llm = ChatOllama(model="llama3.2")
chain = load_summarize_chain(llm, chain_type="stuff")
output = chain.invoke([Document(page_content=table_html)])

# %%
output
# Out:
# {'input_documents': [Document(metadata={}, page_content='<table><thead><tr><th>Model</th><th>BoolQ</th><th>PIQA</th><th>HellaSwag</th><th>WinoG.</th><th>ARC-c</th><th>ARC-c</th><th>OBQA</th><th>Avg</th></tr></thead><tbody><tr><td>GPT4AII-J 6B v1.0*</td><td>73.4</td><td>74.8</td><td>63.4</td><td>64.7</td><td>54.9</td><td>36</td><td>40.2</td><td>58.2</td></tr><tr><td>GPT4AII-J v1.1-breezy*</td><td>74</td><td>75.1</td><td>63.2</td><td>63.6</td><td>55.4</td><td>34.9</td><td>38.4</td><td>SL</td></tr><tr><td>GPT4AII-J v1.2-jazzy*</td><td>74.8</td><td>74.9</td><td>63.6</td><td>638</td><td>56.6</td><td>35.3</td><td>41</td><td>58.6</td></tr><tr><td>GPT4AIIL-J v1.3-groovy*</td><td>73.6</td><td>74.3</td><td>63.8</td><td>63.5</td><td>57.7</td><td>35</td><td>38.8</td><td>58.1</td></tr><tr><td>GPT4AII-J Lora 6B*</td><td>68.6</td><td>75.8</td><td>66.2</td><td>63.5</td><td>56.4</td><td>35.7</td><td>402</td><td>58.1</td></tr><tr><td>GPT4AIl LLaMa Lora 7B*</td><td>73.1</td><td>716</td><td>721</td><td>
aicML-Team, 2023)</td><td>771</td><td>78.2</td><td>74S</td><td>67.5</td><td>69.4</td><td>43.3</td><td>44.2</td><td>64.9</td></tr><tr><td>Wizard 7B xu et al., 2023)</td><td>4</td><td>712</td><td>69.9</td><td>66,5</td><td>56.8</td><td>40.5</td><td>42.6</td><td>61,7</td></tr><tr><td>Wizard 7B Uncensored (Xu et al., 2023)</td><td>717</td><td>74.2</td><td>68</td><td>65,2</td><td>53.5</td><td>38.7</td><td>416</td><td>59.8</td></tr><tr><td>Wizard 13B Uncensored (Xu et al,, 2023)</td><td>784</td><td>15.5</td><td>RA]</td><td>69.5</td><td>57.5</td><td>40.4</td><td>44</td><td>62.5</td></tr><tr><td>GPT4-x-Vicuna-13b (Nous-Research, 2023a)</td><td>813</td><td>75</td><td>75.2</td><td>65</td><td>58.7</td><td>43,9</td><td>43.6</td><td>63,2</td></tr><tr><td>Falcon 7b (Almazrouei et al., 2023)</td><td>73.6</td><td>80.7</td><td>76.3</td><td>67,3</td><td>7m</td><td>43.3</td><td>44.4</td><td>65,2</td></tr><tr><td>Falcon 7b instruct (Almazrouei et al., 2023)</td><td>709</td><td>78.6</td><td>69.8</td><td>66.7</td><td>67.9</td><td>42.7</td><td>412</td><td>62.5</td></tr></tbody></table>')],
 'output_text': 'This text appears to be a table or list of various conversational AI models, with each model listed with its name, performance metrics (such as accuracy, F1 score, and other evaluation metrics), and sometimes additional information. The models are categorized under different subheadings, such as "Wizard", "GPT4-x-Vicuna-13b", and others.\n\nSome notable observations from the table include:\n\n* Many models achieve high accuracy and F1 scores, indicating strong performance in conversational AI tasks.\n* Some models have significantly lower performance metrics, suggesting areas for improvement.\n* Certain models are listed as having been developed by specific organizations or research teams (e.g. "MosaicML-Team", "Nous-Research").\n* There is a wide range of model names and architectures represented, including "GPT4-x-Vicuna-13b" and "Falcon 7b".\n\nWithout more context or information about the specific use case or task being evaluated, it\'s difficult to draw broader conclusions from this table. However, it provides a snapshot of the current state of conversational AI models and their performance on various tasks.'}

# %%
print(output['output_text'])
# Out:
# This text appears to be a table or list of various conversational AI models, with each model listed with its name, performance metrics (such as accuracy, F1 score, and other evaluation metrics), and sometimes additional information. The models are categorized under different subheadings, such as "Wizard", "GPT4-x-Vicuna-13b", and others.
#
# Some notable observations from the table include:
#
# * Many models achieve high accuracy and F1 scores, indicating strong performance in conversational AI tasks.
# * Some models have significantly lower performance metrics, suggesting areas for improvement.
# * Certain models are listed as having been developed by specific organizations or research teams (e.g. "MosaicML-Team", "Nous-Research").
# * There is a wide range of model names and architectures represented, including "GPT4-x-Vicuna-13b" and "Falcon 7b".
#
# ...

# %%
import pandas as pd

# Convert HTML table to pandas DataFrame
dfs = pd.read_html(table_html)

# %%
dfs
# Out:
# [                                                Model  BoolQ   PIQA HellaSwag  \
#  0                                  GPT4AII-J 6B v1.0*   73.4   74.8      63.4
#  1                              GPT4AII-J v1.1-breezy*   74.0   75.1      63.2
#  2                               GPT4AII-J v1.2-jazzy*   74.8   74.9      63.6
#  3                             GPT4AIIL-J v1.3-groovy*   73.6   74.3      63.8
#  4                                  GPT4AII-J Lora 6B*   68.6   75.8      66.2
#  5                              GPT4AIl LLaMa Lora 7B*   73.1  716.0       721
#  6                                 GPT4All 13B snoozy*   83.3   79.2        15
#  7                                      GPT4AIl Falcon   71.6   79.8       749
#  8                  Nous-Hermes (Nous-Research, 2023b)   79.5   78.9        80
#  9                 Nous-Hermes2 (Nous-Research, 2023c)   83.9   80.7      80.1
#  10                 Nous-Puffin (Nous-Research, 2023d)  815.0   80.7      80.4
# ...

# %%
# Assuming there's only one table, get the DataFrame
df = dfs[0]

# Now you have the DataFrame
print(df)
# Out:
#                                                 Model  BoolQ   PIQA HellaSwag  \
# 0                                  GPT4AII-J 6B v1.0*   73.4   74.8      63.4
# 1                              GPT4AII-J v1.1-breezy*   74.0   75.1      63.2
# 2                               GPT4AII-J v1.2-jazzy*   74.8   74.9      63.6
# 3                             GPT4AIIL-J v1.3-groovy*   73.6   74.3      63.8
# 4                                  GPT4AII-J Lora 6B*   68.6   75.8      66.2
# 5                              GPT4AIl LLaMa Lora 7B*   73.1  716.0       721
# 6                                 GPT4All 13B snoozy*   83.3   79.2        15
# 7                                      GPT4AIl Falcon   71.6   79.8       749
# 8                  Nous-Hermes (Nous-Research, 2023b)   79.5   78.9        80
# 9                 Nous-Hermes2 (Nous-Research, 2023c)   83.9   80.7      80.1
# 10                 Nous-Puffin (Nous-Research, 2023d)  815.0   80.7      80.4
# ...

# %%
df.shape
# Out:
# (36, 9)

# %%
df.head()
# Out:
#                      Model  BoolQ  PIQA HellaSwag WinoG. ARC-c ARC-c.1  OBQA  \
# 0       GPT4AII-J 6B v1.0*   73.4  74.8      63.4   64.7  54.9      36  40.2
# 1   GPT4AII-J v1.1-breezy*   74.0  75.1      63.2   63.6  55.4    34.9  38.4
# 2    GPT4AII-J v1.2-jazzy*   74.8  74.9      63.6    638  56.6    35.3    41
# 3  GPT4AIIL-J v1.3-groovy*   73.6  74.3      63.8   63.5  57.7      35  38.8
# 4       GPT4AII-J Lora 6B*   68.6  75.8      66.2   63.5  56.4    35.7   402
#
#     Avg
# 0  58.2
# 1    SL
# 2  58.6
# 3  58.1
# 4  58.1

# %%
# %pip install sqlalchemy psycopg2
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
#   Using cached psycopg2-2.9.10-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# ...
# Using cached psycopg2-2.9.10-cp312-cp312-win_amd64.whl (1.2 MB)
# ...

# %%
from datetime import datetime

timestamp = datetime.now().strftime("%Y_%m_%d__%H-%M")  # Format: YYYYMMDD_HHMMSS
filename = f"C:/Users/Ankit kumar singh/Downloads/doc_data_{timestamp}.csv"

# Save the DataFrame
df.to_csv(filename, index=False)
print(f"File saved as {filename}")
# Out:
# File saved as C:/Users/Ankit kumar singh/Downloads/doc_data_2025_01_05__17-37.csv

# %%
# %pip install lxml
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
